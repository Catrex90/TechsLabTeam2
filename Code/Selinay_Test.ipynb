# %%
import pandas as pd
# code that had be used for extracting the data

# Corona
# print("Corona Düsseldorf")
#df = pd.read_csv("C:/Users/jkr/Documents/9 Computer/Informatik/Techlabs/DataScienceTrack/Project_DS/VSCode/techLabs/Datasets/Raw/Corona/duesseldorf_corona.csv")

#display(df)
#print(df)

# Airquality Particulate Matter

print("Airquality Particulate Matter - 2020 - 2022")
df = pd.read_csv("/Users/selinaycengiz/Documents/TechLabs Group 2/TechsLabTeam2/Test/2010-2019_Ozon_NRW_Stundenmittelwert.csv", encoding="ISO-8859-1", sep=";", header=None)

#print(df.dtypes)

display(df)

# delete the first 2 lines
df = df.drop([0, 1]).reset_index(drop=True)

display(df)
#print(df)
# Out:
# Airquality Particulate Matter - 2020 - 2022
# /var/folders/7v/_l30msh559v3md8xfz89t3q80000gn/T/ipykernel_1459/2718187643.py:14: DtypeWarning: Columns (8,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/selinaycengiz/Documents/TechLabs Group 2/TechsLabTeam2/Test/2010-2019_Ozon_NRW_Stundenmittelwert.csv", encoding="ISO-8859-1", sep=";", header=None)
#                                                       0         1   \
# 0      # "Tabelle für Zeitbereich: 01.01.2010 00:00 b...       NaN
# 1                                             # "Quelle"       NaN
# 2                                                  Datum      Zeit
# 3                                             01.01.2010     01:00
# 4                                             01.01.2010     02:00
# ...                                                  ...       ...
# 87646                                         31.12.2019     20:00
# 87647                                         31.12.2019     21:00
# 87648                                         31.12.2019     22:00
# 87649                                         31.12.2019     23:00
# 87650                                         31.12.2019  24:00:00
#
#                                   2                              3   \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2      AABU O3 1H Mittelwert [µg/m³]  BIEL O3 1H Mittelwert [µg/m³]
# 3                                 13                            NaN
# 4                                 20                             43
# ...                              ...                            ...
# 87646                              5                             20
# 87647                             <4                             19
# 87648                              8                             18
# 87649                              9                             26
# 87650                              8                             27
#
#                                   4                              5   \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2      BORG O3 1H Mittelwert [µg/m³]  BOTT O3 1H Mittelwert [µg/m³]
# 3                                 54                             24
# 4                                 56                             38
# ...                              ...                            ...
# 87646                             33                             37
# 87647                             21                             39
# 87648                             33                             27
# 87649                             27                             13
# 87650                            NaN                              8
#
#                                   6                              7   \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2      CHOR O3 1H Mittelwert [µg/m³]  DMD2 O3 1H Mittelwert [µg/m³]
# 3                                NaN                             20
# 4                                 19                             34
# ...                              ...                            ...
# 87646                              5                             53
# 87647                              4                             50
# 87648                              4                             39
# 87649                             <4                             36
# 87650                             <4                             19
#
#                                   8                              9   ...  \
# 0                                NaN                            NaN  ...
# 1                                NaN                            NaN  ...
# 2      DWER O3 1H Mittelwert [µg/m³]  EIFE O3 1H Mittelwert [µg/m³]  ...
# 3                                NaN                             18  ...
# 4                                NaN                             19  ...
# ...                              ...                            ...  ...
# 87646                              6                             18  ...
# 87647                             <4                             31  ...
# 87648                             <4                             35  ...
# 87649                            NaN                            NaN  ...
# 87650                             <4                             48  ...
#
#                                   21                             22  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2      ROTH O3 1H Mittelwert [µg/m³]  SHW2 O3 1H Mittelwert [µg/m³]
# 3                                 <4                             44
# 4                                  6                             42
# ...                              ...                            ...
# 87646                             42                             48
# 87647                             51                             35
# 87648                             58                             25
# 87649                             61                            NaN
# 87650                             59                              7
#
#                                   23                             24  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2      SICK O3 1H Mittelwert [µg/m³]  SOES O3 1H Mittelwert [µg/m³]
# 3                                 41                             45
# 4                                NaN                             47
# ...                              ...                            ...
# 87646                             <4                             49
# 87647                             <4                             47
# 87648                             <4                             41
# 87649                              5                             39
# 87650                             <4                             43
#
#                                   25                             26  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2      SOLI O3 1H Mittelwert [µg/m³]  STYR O3 1H Mittelwert [µg/m³]
# 3                                 20                            NaN
# 4                                 30                             33
# ...                              ...                            ...
# 87646                             32                             30
# 87647                             30                             19
# 87648                             35                             20
# 87649                             28                            NaN
# 87650                             24                             16
#
#                                   27                             28  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2      VESN O3 1H Mittelwert [µg/m³]  WALS O3 1H Mittelwert [µg/m³]
# 3                                NaN                             31
# 4                                NaN                             44
# ...                              ...                            ...
# 87646                            NaN                             <4
# 87647                            NaN                             <4
# 87648                            NaN                             <4
# 87649                            NaN                             <4
# 87650                            NaN                             <4
#
#                                   29                             30
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2      WESE O3 1H Mittelwert [µg/m³]  WULA O3 1H Mittelwert [µg/m³]
# 3                                 52                            NaN
# 4                                 53                             33
# ...                              ...                            ...
# 87646                              6                             37
# 87647                             <4                             13
# 87648                             <4                             <4
# 87649                             <4                             <4
# 87650                              7                              9
#
# [87651 rows x 31 columns]
#                0         1                              2   \
# 0           Datum      Zeit  AABU O3 1H Mittelwert [µg/m³]
# 1      01.01.2010     01:00                             13
# 2      01.01.2010     02:00                             20
# 3      01.01.2010     03:00                             28
# 4      01.01.2010     04:00                             31
# ...           ...       ...                            ...
# 87644  31.12.2019     20:00                              5
# 87645  31.12.2019     21:00                             <4
# 87646  31.12.2019     22:00                              8
# 87647  31.12.2019     23:00                              9
# 87648  31.12.2019  24:00:00                              8
#
#                                   3                              4   \
# 0      BIEL O3 1H Mittelwert [µg/m³]  BORG O3 1H Mittelwert [µg/m³]
# 1                                NaN                             54
# 2                                 43                             56
# 3                                 44                             59
# 4                                 47                             62
# ...                              ...                            ...
# 87644                             20                             33
# 87645                             19                             21
# 87646                             18                             33
# 87647                             26                             27
# 87648                             27                            NaN
#
#                                   5                              6   \
# 0      BOTT O3 1H Mittelwert [µg/m³]  CHOR O3 1H Mittelwert [µg/m³]
# 1                                 24                            NaN
# 2                                 38                             19
# 3                                 43                             22
# 4                                 44                             20
# ...                              ...                            ...
# 87644                             37                              5
# 87645                             39                              4
# 87646                             27                              4
# 87647                             13                             <4
# 87648                              8                             <4
#
#                                   7                              8   \
# 0      DMD2 O3 1H Mittelwert [µg/m³]  DWER O3 1H Mittelwert [µg/m³]
# 1                                 20                            NaN
# 2                                 34                            NaN
# 3                                 38                            NaN
# 4                                 35                            NaN
# ...                              ...                            ...
# 87644                             53                              6
# 87645                             50                             <4
# 87646                             39                             <4
# 87647                             36                            NaN
# 87648                             19                             <4
#
#                                   9   ...                             21  \
# 0      EIFE O3 1H Mittelwert [µg/m³]  ...  ROTH O3 1H Mittelwert [µg/m³]
# 1                                 18  ...                             <4
# 2                                 19  ...                              6
# 3                                 25  ...                             11
# 4                                NaN  ...                             18
# ...                              ...  ...                            ...
# 87644                             18  ...                             42
# 87645                             31  ...                             51
# 87646                             35  ...                             58
# 87647                            NaN  ...                             61
# 87648                             48  ...                             59
#
#                                   22                             23  \
# 0      SHW2 O3 1H Mittelwert [µg/m³]  SICK O3 1H Mittelwert [µg/m³]
# 1                                 44                             41
# 2                                 42                            NaN
# 3                                 41                             54
# 4                                 43                             54
# ...                              ...                            ...
# 87644                             48                             <4
# 87645                             35                             <4
# 87646                             25                             <4
# 87647                            NaN                              5
# 87648                              7                             <4
#
#                                   24                             25  \
# 0      SOES O3 1H Mittelwert [µg/m³]  SOLI O3 1H Mittelwert [µg/m³]
# 1                                 45                             20
# 2                                 47                             30
# 3                                 48                             28
# 4                                NaN                             36
# ...                              ...                            ...
# 87644                             49                             32
# 87645                             47                             30
# 87646                             41                             35
# 87647                             39                             28
# 87648                             43                             24
#
#                                   26                             27  \
# 0      STYR O3 1H Mittelwert [µg/m³]  VESN O3 1H Mittelwert [µg/m³]
# 1                                NaN                            NaN
# 2                                 33                            NaN
# 3                                 43                            NaN
# 4                                 42                            NaN
# ...                              ...                            ...
# 87644                             30                            NaN
# 87645                             19                            NaN
# 87646                             20                            NaN
# 87647                            NaN                            NaN
# 87648                             16                            NaN
#
#                                   28                             29  \
# 0      WALS O3 1H Mittelwert [µg/m³]  WESE O3 1H Mittelwert [µg/m³]
# 1                                 31                             52
# 2                                 44                             53
# 3                                 46                             57
# 4                                 48                             58
# ...                              ...                            ...
# 87644                             <4                              6
# 87645                             <4                             <4
# 87646                             <4                             <4
# 87647                             <4                             <4
# 87648                             <4                              7
#
#                                   30
# 0      WULA O3 1H Mittelwert [µg/m³]
# 1                                NaN
# 2                                 33
# 3                                 34
# 4                                 39
# ...                              ...
# 87644                             37
# 87645                             13
# 87646                             <4
# 87647                             <4
# 87648                              9
#
# [87649 rows x 31 columns]
